# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\william\pycharmprojects\csd-4523\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Create data
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 6]

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(categories, values, color='skyblue')

# Add title and labels
plt.title('A Simple Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## This is a header
